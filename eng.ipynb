# %%
import requests
import json

r = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', #, 3에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": 'ice cream,',
    }))
input_text = r.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)
# Out:
# [501, 8566, 11]

# %%
import requests
import json

company = "Samsung" #(최대 10글자)
context = "Electronic device" #(최대 15글자)

input_ = company + ' ' + context + ','
print(input_)

r = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', #, 3에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": input_,
    }))
input_text = r.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)
# Out:
# Samsung Electronic device,
# [32334, 19508, 3335, 11]

# %%
import requests
import json


r = requests.post(
    'https://train-by345gzt9m0z4kx88qrm-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', #, 2에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": input_text,
  "num_samples": 20,
  "length": 20
    }))

#슬로건 추가
slogan_list = r.json()
print(slogan_list)
# Out:
# {'code': 503, 'type': 'InternalServerException', 'message': 'Prediction failed'}

# %%
import requests
import json
from transformers import AutoTokenizer # For Encoding and Decoding 
autoTokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
for eng_slogan in slogan_list:
    text = autoTokenizer.decode(eng_slogan, skip_special_tokens=True)
    slogan = text.split('\n')[0]
    slogan = slogan.split(',')[1:]
    slogan = ', '.join(slogan)
    print(slogan)

# %%
import requests
import json
from transformers import AutoTokenizer # For Encoding and Decoding 

company = "ice" #(최대 10글자)
context = "cream" #(최대 15글자)

input_ = 'automotive engine manufacturer,'
print(input_)

#preprocess
a = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', 
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": input_,
    }))

input_text = a.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)

#slogan generate
r = requests.post(
    'https://train-by345gzt9m0z4kx88qrm-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', # M 2에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": encode_list,
  "num_samples": 20,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
for slogan in r.json():
  slogan_list.append(slogan)
  
  
autoTokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
for eng_slogan in slogan_list:
    text = autoTokenizer.decode(eng_slogan, skip_special_tokens=True)
    slogan = text.split('\n')[0]
    slogan = slogan.split(',')[1:]
    slogan = ', '.join(slogan)
    print(slogan)
# Out:
# automotive engine manufacturer,
# [2306, 296, 19138, 3113, 11554, 11]
# Our customers want better.
# Inventing new technologies for tomorrow.
# Driven by a passion to help you make the most of your life.
# Automotive design designed for performance.
# Making your future a reality.
# When it comes to performance,  it's the only reason to go.
# Power to win.
# Engine of the Future.
# Power to go.
# Fueled by technology.
# Engineer in your vehicle.
# Our focus lies in technology.
# Making the world move.
# Engine-up to power a Formula One car.
# Because of the way you move.
# A true heritage of design excellence.
# Everyday you drive,  we're here.
# Automotive technology is your partner.
# Excellence in performance.
# Exclusive performance.

# %%
import requests
import json
from transformers import AutoTokenizer # For Encoding and Decoding 

company = "ice" #(최대 10글자)
context = "cream" #(최대 15글자)

input_ = 'automotive engine manufacturer,'
print(input_)

#preprocess
a = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', 
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": input_,
    }))

input_text = a.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)

#slogan generate
r = requests.post(
    'https://train-ro9p039i9k41i9ah00ag-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', # M 3에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": encode_list,
  "num_samples": 20,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
for slogan in r.json():
  slogan_list.append(slogan)
  
  
autoTokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
for eng_slogan in slogan_list:
    text = autoTokenizer.decode(eng_slogan, skip_special_tokens=True)
    slogan = text.split('\n')[0]
    slogan = slogan.split(',')[1:]
    slogan = ', '.join(slogan)
    print(slogan)
# Out:
# automotive engine manufacturer,
# [2306, 296, 19138, 3113, 11554, 11]
# Your car is yours.
# Automotive performance without compromise.
# Creating value. Removing stress.
# Creating the future.
# Keeping your engine going all day!
# Better performance from cheaper.
# Masters of performance.
# Power to move.
# We do it right the first time.
# Drive fast and drive well.
# The world's first-generation of V8 engines.
# Automotive that works.
# Keeping fuel safe.
# The lightest car on the road.
# Technology that helps you make the right choices.
# Competing on performance,  not fuel!
# Engine of performance.
# For the man who likes a challenge!
# Engines for the next generation of vehicles.
# Your future is ours!

# %%
import requests
import json
from transformers import AutoTokenizer # For Encoding and Decoding 

company = "ice" #(최대 10글자)
context = "cream" #(최대 15글자)

input_ = 'automotive engine manufacturer,'
print(input_)

#preprocess
a = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', 
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": input_,
    }))

input_text = a.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)

#slogan generate
r = requests.post(
    'https://train-nmji0oaus6bnuz71trcg-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', # M 4에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": encode_list,
  "num_samples": 20,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
for slogan in r.json():
  slogan_list.append(slogan)
  
  
autoTokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
for eng_slogan in slogan_list:
    text = autoTokenizer.decode(eng_slogan, skip_special_tokens=True)
    slogan = text.split('\n')[0]
    slogan = slogan.split(',')[1:]
    slogan = ', '.join(slogan)
    print(slogan)
# Out:
# automotive engine manufacturer,
# [2306, 296, 19138, 3113, 11554, 11]
# We build it. Take it with you.
# Technology is everything.
# Porsche. The only thing we care about.
# Driven. Motivated. Robotics.
# Achieving the future together.
# The ultimate fuel economy car.
# Mentoring technology.
# Innovative solutions.
# It all begins with a Ford.
# Building more.
# Making the right choices for the future.
# Competition's Best.
# We strive for excellence.
# Your choice of performance powertrain.
# Building to last.
# A better driving experience.
# We're ready.
# The power of the mind.
# When you know what you want,  you can have it.
# Achieving our highest.

# %%
import requests
import json
from transformers import AutoTokenizer # For Encoding and Decoding 

input_ = 'apple iphone'
print(input_)

#preprocess
a = requests.post(
    'https://main-gpt-2-server-gkswjdzz.endpoint.ainize.ai/preprocess', 
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "context": input_,
    }))

input_text = a.json().replace('[','').replace(']','').split(", ")

encode_list = []
for i in input_text :
  i = int(i)
  encode_list.append(i)

print(encode_list)

#slogan generate
r = requests.post(
    # 'https://train-2yh9mhbbfwvp1fu3a9mv-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', # M 3에포크 애플 슬로건
    'https://train-shl4h9fvjomb8xlpykyj-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-small-finetune', #S 5에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": encode_list,
  "num_samples": 20,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
for slogan in r.json():
  slogan_list.append(slogan)
  
  
autoTokenizer = AutoTokenizer.from_pretrained("gpt2-medium")
for eng_slogan in slogan_list:
  print('='*40)
  text = autoTokenizer.decode(eng_slogan, skip_special_tokens=True)
  slogan = text.split('\n')[0]
  # slogan = slogan.split(',')[1:]
  # slogan = ', '.join(slogan)
  print(slogan)
# Out:
# apple iphone
# [18040, 220, 13323, 505]

# %%
import requests
import json


r = requests.post(
    'https://train-ro9p039i9k41i9ah00ag-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', #, 3에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": 'ice cream',
  "num_samples": 100,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
print(r.json)
# Out:
# <bound method Response.json of <Response [503]>>

# %%
import requests
import json


r = requests.post(
    'https://train-nmji0oaus6bnuz71trcg-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-en-medium-finetune', #, 4에포크
    headers = {'Content-Type' : 'application/json'
               },
    data=json.dumps({
  "text": 'ice cream',
  "num_samples": 100,
  "length": 20
    }))

#슬로건 추가
slogan_list = []
for slogan in r.json():
    print(slogan)
# Out:
# code
# type
# message
